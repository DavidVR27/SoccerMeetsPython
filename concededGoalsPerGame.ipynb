# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("PremierLeagueGK_Stats.csv")

# %%
df.head()
# Out:
#          Squad  # Pl  MP  Starts   Min   90s  GA  GA90  SoTA  Saves  ...   W  \
# 0      Arsenal     1  38      38  3420  38.0  34  0.89   120     86  ...  20
# 1  Aston Villa     2  38      38  3420  38.0  51  1.34   156    104  ...  19
# 2  Bournemouth     3  38      38  3420  38.0  46  1.21   172    126  ...  15
# 3    Brentford     2  38      38  3420  38.0  57  1.50   207    153  ...  16
# 4     Brighton     2  38      38  3420  38.0  59  1.55   147     90  ...  16
#
#     D   L  CS   CS%  PKatt  PKA  PKsv  PKm  Save%.1
# 0  14   4  13  34.2      3    3     0    0      0.0
# 1   9  10   9  23.7      3    2     1    0     33.3
# 2  11  12   9  23.7      4    4     0    0      0.0
# 3   8  14   8  21.1      1    1     0    0      0.0
# 4  13   9   8  21.1      9    9     0    0      0.0
#
# [5 rows x 21 columns]

# %%
# o -> Puntos del plot
plt.plot(df['SoTA'],df['Save%'],'o')

# %%
# Creando area del plot
fig, ax = plt.subplots()

# Tamaño del plot
fig.set_size_inches(5,5)

plt.plot(df['SoTA'],df['Save%'],"*")

# Labels
ax.set_title("Shots Against vs Save %")
ax.set_xlabel("SoTA")
ax.set_ylabel("Save%")

plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7,5)

# Scatter plot
plt.plot(df['SoTA'], df['Save%'], 'o')

# Líneas de cuadrantes usando los límites reales de los datos
plt.plot([df['SoTA'].mean(), df['SoTA'].mean()],
         [df['Save%'].min()-1, df['Save%'].max()+1], 'k-', linestyle="--", lw=1)

plt.plot([df['SoTA'].min()-5, df['SoTA'].max()+5],
         [df['Save%'].mean(), df['Save%'].mean()], 'k-', linestyle="--", lw=1)

ax.set_title("Shots on Target Against vs Save %")
ax.set_xlabel("SoTA")
ax.set_ylabel("Save%")

plt.show()
# Out:
# C:\Users\davo2\AppData\Local\Temp\ipykernel_3620\613316321.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot([df['SoTA'].mean(), df['SoTA'].mean()],
# C:\Users\davo2\AppData\Local\Temp\ipykernel_3620\613316321.py:11: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot([df['SoTA'].min()-5, df['SoTA'].max()+5],

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7,5)

# Scatter plot
plt.plot(df['SoTA'], df['Save%'], 'o')

# Líneas de cuadrantes usando los límites reales de los datos
plt.plot([df['SoTA'].mean(), df['SoTA'].mean()],
         [df['Save%'].min()-1, df['Save%'].max()+1], 'k-', linestyle="--", lw=1)

plt.plot([df['SoTA'].min()-5, df['SoTA'].max()+5],
         [df['Save%'].mean(), df['Save%'].mean()], 'k-', linestyle="--", lw=1)

ax.set_title("Shots on Target Against vs Save %")
ax.set_xlabel("SoTA")
ax.set_ylabel("Save%")

ax.text(110,76,"Less shots on target, higher save %", color="black", size=8)
ax.text(190,62,"More shots on target, lower save %", color="black", size=8)

plt.show()
# Out:
# C:\Users\davo2\AppData\Local\Temp\ipykernel_3620\3179524285.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot([df['SoTA'].mean(), df['SoTA'].mean()],
# C:\Users\davo2\AppData\Local\Temp\ipykernel_3620\3179524285.py:11: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot([df['SoTA'].min()-5, df['SoTA'].max()+5],
